# %%
import numpy as np  # Import library numpy untuk operasi numerik
import pandas as pd  # Import library pandas untuk manipulasi data

# %%
import json  # Import library json untuk membaca data dari file JSON

with open('../data/lisa.json', 'r') as f:
    data = json.load(f)  # Membaca data dari file JSON dan menyimpannya dalam variabel 'data'

df = pd.DataFrame(data['intents'])  # Membuat DataFrame dari bagian 'intents' dalam data JSON
df
# Out:
#                             tag  \
# 0                         salam
# 1                          pagi
# 2                         siang
# 3                          sore
# 4                         malam
# 5                       penutup
# 6                  terima_kasih
# 7                  tidak_respon
# 8                  tentang_saya
# 9                     kemampuan
# 10                      pembuat
# 11                         nama
# 12                      bantuan
# 13                   apa_itu_tb
# 14                    gejala_tb
# 15                  penyebab_tb
# 16                 penularan_tb
# 17                    risiko_tb
# 18            proses_infeksi_tb
# 19  perbedaan_tb_aktif_tb_laten
# 20                     tb_aktif
# 21                     tb_laten
# 22                      tb_paru
#
#                                              patterns  \
# 0   [Hai, Hei, Hi, Halo, Hola, Hello, Wassap, Yuhu...
# 1                                [Pagi, Selamat pagi]
# 2                              [Siang, Selamat siang]
# 3                                [Sore, Selamat sore]
# 4                              [Malam, Selamat malam]
# 5     [Selamat tinggal, Sampai jumpa, Dadah, Goodbye]
# 6   [Terima kasih, Makasih, Itu sangat membantu, T...
# 7                                                  []
# 8   [Ceritakan tentang dirimu, Siapa kamu?, Apa ya...
# 9   [Apa yang bisa kamu lakukan?, Bisa bantu apa?,...
# 10  [Siapa yang membuatmu?, Bagaimana kamu dibuat?...
# 11         [Nama saya , Saya bernama , Panggil saya ]
# 12  [Bisakah kamu membantu saya?, Tolong bantu say...
# 13  [apa tbc?, apa itu tb?, jelasin tbc, jelasin t...
# 14  [gejala tb, gejala tbc, ciri-ciri tbc, tanda t...
# 15  [penyebab TB, penyebab TBC, kenapa bisa kena T...
# 16  [Penularan tb, Penularan tbc, Bagaimana TBC me...
# 17  [kelompok risiko TBC, siapa yang rentan TBC, s...
# 18  [Proses infeksi,  Bagaimana infeksi tb, Bagaim...
# 19  [perbedaan tb laten dan tb aktif, mengapa tb l...
# 20  [Apa itu TBC aktif?, Apa itu TB aktif?, Jelask...
# 21  [Apa itu TBC laten?, Apa itu TB laten?, Jelask...
# 22  [TB Paru, TBC paru, Apa itu TBC paru?, Apa itu...
#
#                                             responses
# 0   [Halo! Selamat datang di chatbot LISA, asisten...
# 1   [Selamat pagi. Bagaimana perasaan kamu hari ini?]
# 2     [Selamat siang. Bagaimana kabar kamu hari ini?]
# 3   [Selamat sore. Apa yang bisa LISA bantu hari i...
# 4              [Selamat malam. Bagaimana kabar kamu?]
# 5   [Sampai jumpa lagi., Semoga harimu menyenangka...
# 6   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 7   [Maaf, saya tidak mengerti., Silakan lanjutkan...
# 8   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 9   [Saya bisa memberikan informasi umum tentang T...
# 10  [Saya dikembangkan oleh tim Inisiatif Lampung ...
# 11  [Senang bertemu dengan kamu! Bagaimana kabar k...
# 12  [Tentu saja. Bagaimana LISA bisa membantu kamu...
# 13  [TBC merupakan singkatan dari Tuberkulosis. Ya...
# 14  [Gejala utama tuberkulosis (TBC) adalah batuk ...
# 15  [Tuberkulosis (TBC) merupakan penyakit infeksi...
# 16  [Sumber penularan adalah percikan ludah (dropl...
# 17  [Beberapa kelompok yang paling berisiko terken...
# 18  [Bakteri penyebab TBC masuk melalui inhalasi, ...
# 19  [ TBC terbagi menjadi dua jenis yaitu TBC late...
# 20  [Suatu keadaan dimana bakteri penyebab TBC akt...
# 21  [ Suatu keadaaan dimana sistem kekebalan tubuh...
# 22  [TB Paru adalah infeksi yang terjadi di paru-p...

# %%
dic = {"tag":[], "patterns":[], "responses":[]}  # Membuat dictionary kosong untuk menyimpan data yang akan diubah ke DataFrame
for i in range(len(df)):
    ptrns = df[df.index == i]['patterns'].values[0]  # Mengambil pola (patterns) dari DataFrame
    rspns = df[df.index == i]['responses'].values[0]  # Mengambil respons dari DataFrame
    tag = df[df.index == i]['tag'].values[0]  # Mengambil tag dari DataFrame
    for j in range(len(ptrns)):
        dic['tag'].append(tag)  # Menambahkan tag ke dalam dictionary
        dic['patterns'].append(ptrns[j])  # Menambahkan pola ke dalam dictionary
        dic['responses'].append(rspns)  # Menambahkan respons ke dalam dictionary

df = pd.DataFrame.from_dict(dic)  # Membuat DataFrame baru dari dictionary
pd.set_option("display.max_rows", None)  # Menampilkan semua baris DataFrame ketika ditampilkan
df  # Menampilkan DataFrame
# Out:
#                              tag  \
# 0                          salam
# 1                          salam
# 2                          salam
# 3                          salam
# 4                          salam
# 5                          salam
# 6                          salam
# 7                          salam
# 8                          salam
# 9                          salam
# 10                         salam
# 11                         salam
# 12                         salam
# 13                         salam
# 14                         salam
# 15                          pagi
# 16                          pagi
# 17                         siang
# 18                         siang
# 19                          sore
# 20                          sore
# 21                         malam
# 22                         malam
# 23                       penutup
# 24                       penutup
# 25                       penutup
# 26                       penutup
# 27                  terima_kasih
# 28                  terima_kasih
# 29                  terima_kasih
# 30                  terima_kasih
# 31                  terima_kasih
# 32                  tidak_respon
# 33                  tentang_saya
# 34                  tentang_saya
# 35                  tentang_saya
# 36                  tentang_saya
# 37                  tentang_saya
# 38                     kemampuan
# 39                     kemampuan
# 40                     kemampuan
# 41                     kemampuan
# 42                     kemampuan
# 43                     kemampuan
# 44                     kemampuan
# 45                       pembuat
# 46                       pembuat
# 47                       pembuat
# 48                          nama
# 49                          nama
# 50                          nama
# 51                       bantuan
# 52                       bantuan
# 53                       bantuan
# 54                       bantuan
# 55                       bantuan
# 56                       bantuan
# 57                    apa_itu_tb
# 58                    apa_itu_tb
# 59                    apa_itu_tb
# 60                    apa_itu_tb
# 61                    apa_itu_tb
# 62                    apa_itu_tb
# 63                    apa_itu_tb
# 64                    apa_itu_tb
# 65                    apa_itu_tb
# 66                    apa_itu_tb
# 67                    apa_itu_tb
# 68                    apa_itu_tb
# 69                    apa_itu_tb
# 70                    apa_itu_tb
# 71                    apa_itu_tb
# 72                    apa_itu_tb
# 73                    apa_itu_tb
# 74                    apa_itu_tb
# 75                    apa_itu_tb
# 76                    apa_itu_tb
# 77                    apa_itu_tb
# 78                    apa_itu_tb
# 79                    apa_itu_tb
# 80                    apa_itu_tb
# 81                    apa_itu_tb
# 82                    apa_itu_tb
# 83                    apa_itu_tb
# 84                    apa_itu_tb
# 85                    apa_itu_tb
# 86                    apa_itu_tb
# 87                    apa_itu_tb
# 88                    apa_itu_tb
# 89                    apa_itu_tb
# 90                    apa_itu_tb
# 91                    apa_itu_tb
# 92                    apa_itu_tb
# 93                    apa_itu_tb
# 94                    apa_itu_tb
# 95                     gejala_tb
# 96                     gejala_tb
# 97                     gejala_tb
# 98                     gejala_tb
# 99                     gejala_tb
# 100                    gejala_tb
# 101                    gejala_tb
# 102                    gejala_tb
# 103                    gejala_tb
# 104                    gejala_tb
# 105                    gejala_tb
# 106                    gejala_tb
# 107                    gejala_tb
# 108                    gejala_tb
# 109                    gejala_tb
# 110                    gejala_tb
# 111                    gejala_tb
# 112                    gejala_tb
# 113                    gejala_tb
# 114                    gejala_tb
# 115                    gejala_tb
# 116                    gejala_tb
# 117                    gejala_tb
# 118                    gejala_tb
# 119                    gejala_tb
# 120                    gejala_tb
# 121                    gejala_tb
# 122                    gejala_tb
# 123                    gejala_tb
# 124                    gejala_tb
# 125                    gejala_tb
# 126                    gejala_tb
# 127                    gejala_tb
# 128                    gejala_tb
# 129                    gejala_tb
# 130                    gejala_tb
# 131                    gejala_tb
# 132                    gejala_tb
# 133                    gejala_tb
# 134                    gejala_tb
# 135                    gejala_tb
# 136                    gejala_tb
# 137                    gejala_tb
# 138                    gejala_tb
# 139                  penyebab_tb
# 140                  penyebab_tb
# 141                  penyebab_tb
# 142                  penyebab_tb
# 143                  penyebab_tb
# 144                  penyebab_tb
# 145                  penyebab_tb
# 146                  penyebab_tb
# 147                  penyebab_tb
# 148                  penyebab_tb
# 149                  penyebab_tb
# 150                  penyebab_tb
# 151                  penyebab_tb
# 152                  penyebab_tb
# 153                  penyebab_tb
# 154                  penyebab_tb
# 155                  penyebab_tb
# 156                  penyebab_tb
# 157                  penyebab_tb
# 158                  penyebab_tb
# 159                  penyebab_tb
# 160                  penyebab_tb
# 161                  penyebab_tb
# 162                  penyebab_tb
# 163                  penyebab_tb
# 164                  penyebab_tb
# 165                  penyebab_tb
# 166                  penyebab_tb
# 167                  penyebab_tb
# 168                  penyebab_tb
# 169                  penyebab_tb
# 170                  penyebab_tb
# 171                  penyebab_tb
# 172                 penularan_tb
# 173                 penularan_tb
# 174                 penularan_tb
# 175                 penularan_tb
# 176                 penularan_tb
# 177                 penularan_tb
# 178                 penularan_tb
# 179                 penularan_tb
# 180                 penularan_tb
# 181                 penularan_tb
# 182                 penularan_tb
# 183                 penularan_tb
# 184                 penularan_tb
# 185                 penularan_tb
# 186                 penularan_tb
# 187                 penularan_tb
# 188                 penularan_tb
# 189                 penularan_tb
# 190                 penularan_tb
# 191                 penularan_tb
# 192                 penularan_tb
# 193                 penularan_tb
# 194                 penularan_tb
# 195                 penularan_tb
# 196                    risiko_tb
# 197                    risiko_tb
# 198                    risiko_tb
# 199                    risiko_tb
# 200                    risiko_tb
# 201                    risiko_tb
# 202                    risiko_tb
# 203                    risiko_tb
# 204                    risiko_tb
# 205                    risiko_tb
# 206                    risiko_tb
# 207                    risiko_tb
# 208                    risiko_tb
# 209                    risiko_tb
# 210                    risiko_tb
# 211                    risiko_tb
# 212                    risiko_tb
# 213                    risiko_tb
# 214                    risiko_tb
# 215                    risiko_tb
# 216                    risiko_tb
# 217                    risiko_tb
# 218                    risiko_tb
# 219                    risiko_tb
# 220                    risiko_tb
# 221                    risiko_tb
# 222            proses_infeksi_tb
# 223            proses_infeksi_tb
# 224            proses_infeksi_tb
# 225            proses_infeksi_tb
# 226            proses_infeksi_tb
# 227            proses_infeksi_tb
# 228            proses_infeksi_tb
# 229            proses_infeksi_tb
# 230            proses_infeksi_tb
# 231            proses_infeksi_tb
# 232            proses_infeksi_tb
# 233            proses_infeksi_tb
# 234            proses_infeksi_tb
# 235            proses_infeksi_tb
# 236            proses_infeksi_tb
# 237            proses_infeksi_tb
# 238            proses_infeksi_tb
# 239            proses_infeksi_tb
# 240            proses_infeksi_tb
# 241            proses_infeksi_tb
# 242            proses_infeksi_tb
# 243            proses_infeksi_tb
# 244            proses_infeksi_tb
# 245            proses_infeksi_tb
# 246            proses_infeksi_tb
# 247            proses_infeksi_tb
# 248            proses_infeksi_tb
# 249            proses_infeksi_tb
# 250            proses_infeksi_tb
# 251            proses_infeksi_tb
# 252            proses_infeksi_tb
# 253            proses_infeksi_tb
# 254            proses_infeksi_tb
# 255            proses_infeksi_tb
# 256            proses_infeksi_tb
# 257            proses_infeksi_tb
# 258            proses_infeksi_tb
# 259            proses_infeksi_tb
# 260            proses_infeksi_tb
# 261  perbedaan_tb_aktif_tb_laten
# 262  perbedaan_tb_aktif_tb_laten
# 263  perbedaan_tb_aktif_tb_laten
# 264  perbedaan_tb_aktif_tb_laten
# 265  perbedaan_tb_aktif_tb_laten
# 266  perbedaan_tb_aktif_tb_laten
# 267  perbedaan_tb_aktif_tb_laten
# 268                     tb_aktif
# 269                     tb_aktif
# 270                     tb_aktif
# 271                     tb_aktif
# 272                     tb_aktif
# 273                     tb_aktif
# 274                     tb_aktif
# 275                     tb_aktif
# 276                     tb_aktif
# 277                     tb_aktif
# 278                     tb_aktif
# 279                     tb_aktif
# 280                     tb_aktif
# 281                     tb_aktif
# 282                     tb_aktif
# 283                     tb_aktif
# 284                     tb_aktif
# 285                     tb_aktif
# 286                     tb_aktif
# 287                     tb_aktif
# 288                     tb_aktif
# 289                     tb_aktif
# 290                     tb_aktif
# 291                     tb_aktif
# 292                     tb_aktif
# 293                     tb_aktif
# 294                     tb_aktif
# 295                     tb_aktif
# 296                     tb_aktif
# 297                     tb_aktif
# 298                     tb_aktif
# 299                     tb_aktif
# 300                     tb_aktif
# 301                     tb_aktif
# 302                     tb_aktif
# 303                     tb_aktif
# 304                     tb_aktif
# 305                     tb_aktif
# 306                     tb_aktif
# 307                     tb_aktif
# 308                     tb_aktif
# 309                     tb_aktif
# 310                     tb_aktif
# 311                     tb_aktif
# 312                     tb_laten
# 313                     tb_laten
# 314                     tb_laten
# 315                     tb_laten
# 316                     tb_laten
# 317                     tb_laten
# 318                     tb_laten
# 319                     tb_laten
# 320                     tb_laten
# 321                     tb_laten
# 322                     tb_laten
# 323                     tb_laten
# 324                     tb_laten
# 325                     tb_laten
# 326                     tb_laten
# 327                     tb_laten
# 328                     tb_laten
# 329                     tb_laten
# 330                     tb_laten
# 331                     tb_laten
# 332                     tb_laten
# 333                     tb_laten
# 334                     tb_laten
# 335                     tb_laten
# 336                     tb_laten
# 337                     tb_laten
# 338                      tb_paru
# 339                      tb_paru
# 340                      tb_paru
# 341                      tb_paru
# 342                      tb_paru
# 343                      tb_paru
# 344                      tb_paru
# 345                      tb_paru
# 346                      tb_paru
# 347                      tb_paru
#
#                                               patterns  \
# 0                                                  Hai
# 1                                                  Hei
# 2                                                   Hi
# 3                                                 Halo
# 4                                                 Hola
# 5                                                Hello
# 6                                               Wassap
# 7                                                Yuhuu
# 8                                    Ada yang di sana?
# 9                                         Selamat pagi
# 10                                       Selamat siang
# 11                                        Selamat sore
# 12                                       Selamat malam
# 13                   Apakah ini chatbot Tuberkulosis ?
# 14                             Apakah ini chatbot TBC?
# 15                                                Pagi
# 16                                        Selamat pagi
# 17                                               Siang
# 18                                       Selamat siang
# 19                                                Sore
# 20                                        Selamat sore
# 21                                               Malam
# 22                                       Selamat malam
# 23                                     Selamat tinggal
# 24                                        Sampai jumpa
# 25                                               Dadah
# 26                                             Goodbye
# 27                                        Terima kasih
# 28                                             Makasih
# 29                                 Itu sangat membantu
# 30                        Terima kasih atas bantuannya
# 31                                Terima kasih infonya
# 32
# 33                            Ceritakan tentang dirimu
# 34                                         Siapa kamu?
# 35                              Apa yang kamu lakukan?
# 36                                         Apa namamu?
# 37                                       Siapa dirimu?
# 38                         Apa yang bisa kamu lakukan?
# 39                                     Bisa bantu apa?
# 40                                    Apa kemampuanmu?
# 41                          Apa yang dapat kamu bantu?
# 42                                  Kamu bisa apa saja
# 43                                      Kamu bisa apa?
# 44                                      Bisa apa kamu?
# 45                               Siapa yang membuatmu?
# 46                              Bagaimana kamu dibuat?
# 47                                   Siapa penciptamu?
# 48                                          Nama saya
# 49                                       Saya bernama
# 50                                       Panggil saya
# 51                         Bisakah kamu membantu saya?
# 52                                   Tolong bantu saya
# 53                                  Saya butuh bantuan
# 54                           Apa yang bisa kamu bantu?
# 55                                  Tolong dukung saya
# 56                                                  Ya
# 57                                            apa tbc?
# 58                                         apa itu tb?
# 59                                         jelasin tbc
# 60                                          jelasin tb
# 61                                         tbc apa ya?
# 62                                         tb itu apa?
# 142                               kenapa bisa kena TBC
# 143                             TB disebabkan oleh apa
# 144                                 mengapa TB menular
# 145                                 TBC disebabkan apa
# 146                                       penularan TB
# 147                               bagaimana TB menular
# 148                                   faktor risiko TB
# 149                       bagaimana orang bisa kena TB
# 150                           kenapa orang terkena TBC
# 151                              apa penyebab utama TB
# 152                                     TBC karena apa
# 153                         Apa penyebab tuberkulosis?
# 154                          Apa yang menyebabkan TBC?
# 155                          Mengapa TBC bisa terjadi?
# 156                         Apa penyebab penyakit TBC?
# 157               Bagaimana tuberkulosis bisa menular?
# 158                 Apa yang menyebabkan tuberkulosis?
# 159                              Penyebab TBC itu apa?
# 160                     Bagaimana cara penyebaran TBC?
# 161            Apa yang membuat seseorang terkena TBC?
# 162              Saya ingin tahu penyebab tuberkulosis
# 163            Apa faktor risiko utama terjadinya TBC?
# 164  Bagaimana bakteri Mycobacterium tuberculosis m...
# 165            Apa peran bakteri dalam penyebaran TBC?
# 166  Apa yang menyebabkan infeksi tuberkulosis pada...
# 167   Bisakah Anda menjelaskan bagaimana TBC menyebar?
# 168  Apa saja bakteri yang dapat menyebabkan tuberk...
# 169  Mengapa seseorang bisa tertular TBC dari orang...
# 170   Apa faktor yang meningkatkan risiko terkena TBC?
# 171  Bagaimana Mycobacterium tuberculosis menyebabk...
# 172                                       Penularan tb
# 173                                      Penularan tbc
# 174                             Bagaimana TBC menular?
# 175                               Bagaimana tb menular
# 176                                  cara penularan TB
# 177                                     penyebaran TBC
# 178                                  cara TBC menyebar
# 179                             TBC menyebar bagaimana
# 180                               bagaimana TB menular
# 181                             mencegah penularan TBC
# 182                             penularan tuberkulosis
# 183                            TBC menular melalui apa
# 184                                      penyebaran TB
# 185                                       TBC menyebar
# 186                        Apa penyebab penularan TBC?
# 187                         Apa penyebab penularan TB?
# 188              Jelaskan bagaimana cara TBC menyebar.
# 189       Apa yang menyebabkan penularan tuberkulosis?
# 190             Bagaimana cara penularan tuberkulosis?
# 191                  Apakah TBC menular melalui udara?
# 192              Bagaimana tuberkulosis bisa menyebar?
# 193  Apa yang harus dilakukan untuk mencegah penula...
# 194       Tolong beri tahu saya tentang penularan TBC.
# 195         Bagaimana cara TBC menyebar di masyarakat?
# 196                                kelompok risiko TBC
# 197                              siapa yang rentan TBC
# 198                            siapa yang berisiko TBC
# 199                      siapa yang mudah tertular TBC
# 200                       Siapa yang dapat tertular tb
# 201                       kelompok berisiko tinggi TBC
# 202                      TBC pada siapa lebih berisiko
# 203                             siapa yang berisiko TB
# 204            Siapa yang paling berisiko terkena TBC?
# 205                               siapa yang rentan TB
# 206                         kelompok tinggi risiko TBC
# 207                              risiko TBC pada siapa
# 208                        siapa yang bisa terkena TBC
# 209                             siapa harus waspada TB
# 210                                  risiko tinggi TBC
# 211                       siapa yang mudah terkena TBC
# 212                              TBC risiko pada siapa
# 213  Siapa saja yang berisiko tinggi terkena tuberk...
# 214                      Siapa yang dapat tertular tbc
# 215             Apa kelompok yang rentan terhadap TBC?
# 216                     TBC lebih berisiko pada siapa?
# 217    Siapa yang harus waspada terhadap tuberkulosis?
# 218                       Apa saja risiko terkena TBC?
# 219            Siapa yang paling mudah terinfeksi TBC?
# 220  Apa kelompok orang yang berisiko tinggi terken...
# 221  Siapa yang harus lebih berhati-hati terhadap TBC?
# 222                                     Proses infeksi
# 223                               Bagaimana infeksi tb
# 224                              Bagaimana infeksi tbc
# 225                        Bagaimana proses infeksi tb
# 226                       Bagaimana proses infeksi tbc
# 227                                 proses infeksi TBC
# 228                                          proses TB
# 229                               bagaimana TB infeksi
# 230                               infeksi TB bagaimana
# 231                           proses masuk bakteri TBC
# 232                                bagaimana TBC masuk
# 233                                 proses bakteri TBC
# 234                      bagaimana bakteri TBC bekerja
# 235                   bagaimana TBC mempengaruhi tubuh
# 236                                        TBC infeksi
# 237                                infeksi bakteri TBC
# 238                                   TBC proses masuk
# 239                                      TBC dan tubuh
# 240                                TBC bagaimana masuk
# 241                                infeksi bakteri TBC
# 242                      bagaimana bakteri TBC bekerja
# 243                          TBC masuk tubuh bagaimana
# 244                                 TBC proses infeksi
# 245                                proses TBC di tubuh
# 246                       TBC masuk ke tubuh bagaimana
# 247            bagaimana bakteri TB mempengaruhi tubuh
# 248                             TBC masuk ke paru-paru
# 249     Bagaimana bakteri penyebab TBC masuk ke tubuh?
# 250                       Jelaskan proses infeksi TBC.
# 251                  Bagaimana prosesnya didalam tubuh
# 252     Apa yang terjadi setelah bakteri TBC terhirup?
# 253  Bagaimana bakteri TBC mempengaruhi tubuh setel...
# 254  Apa yang terjadi ketika bakteri TBC masuk ke p...
# 255                    Proses infeksi TBC seperti apa?
# 256  Apa tiga kemungkinan setelah bakteri TBC masuk...
# 257  Bagaimana tubuh menangani bakteri TBC setelah ...
# 258  Apa yang terjadi pada bakteri TBC setelah masu...
# 259  bagaimana tb ini prosesnya bisa masuk kedalam ...
# 260  bagaimana tbc ini prosesnya bisa masuk kedalam...
# 261                    perbedaan tb laten dan tb aktif
# 262              mengapa tb laten dan tb aktif berbeda
# 263      Apa perbedaan antara TBC laten dan TBC aktif?
# 264                  Jelaskan TBC laten dan TBC aktif.
# 265        Bagaimana TBC laten berbeda dari TBC aktif?
# 266    sebutkan perbedaan antara tb laten dan tb aktif
# 267  sebutkan perbedaan antara tbc laten dan tbc aktif
# 268                                 Apa itu TBC aktif?
# 269                                  Apa itu TB aktif?
# 270                        Jelaskan tentang TBC aktif.
# 271                        Bagaimana gejala TBC aktif?
# 272  Apa yang harus dilakukan jika seseorang memili...
# 273                Bagaimana cara menangani TBC aktif?
# 274                    Apa pengobatan untuk TBC aktif?
# 275  Apa yang terjadi jika pengobatan TBC aktif tid...
# 276  Apa yang harus diperhatikan dalam pengobatan T...
# 277  Bagaimana cara mencegah penularan dari TBC aktif?
# 278                                  TBC aktif apa itu
# 279                                   TB aktif apa itu
# 280                                   gejala TBC aktif
# 281                               pengobatan TBC aktif
# 282                           cara menangani TBC aktif
# 283                                TBC aktif penularan
# 284                            TBC aktif cara mencegah
# 285           apa yang harus dilakukan untuk TBC aktif
# 286              TBC aktif apa yang harus diperhatikan
# 287                            cara mencegah TBC aktif
# 288                apa itu TBC aktif dan pengobatannya
# 289                           cara mengatasi TBC aktif
# 290              TBC aktif apa yang perlu diperhatikan
# 291                           TBC aktif dan pengobatan
# 292                                    gejala TB aktif
# 293                               penanganan TBC aktif
# 294                                pengobatan TB aktif
# 295                                  cara mencegah TBC
# 296                                 TBC aktif apa saja
# 297                                penularan TBC aktif
# 298                TBC aktif pengobatan dan pencegahan
# 299                            TBC aktif dan gejalanya
# 300  Apa yang terjadi pada tubuh selama infeksi TBC...
# 301  Bagaimana pengobatan TBC aktif mempengaruhi tu...
# 302  Apa langkah-langkah yang harus diambil jika te...
# 303  Bagaimana cara mendeteksi komplikasi dari TBC ...
# 304  Apa saja tanda-tanda bahwa pengobatan TBC akti...
# 305  Bagaimana cara mengatasi efek samping dari pen...
# 306  Apa yang harus diperhatikan dalam perawatan ja...
# 307  Bagaimana cara menangani TBC aktif pada anak-a...
# 308  Apa strategi pencegahan yang efektif untuk men...
# 309  Bagaimana pengobatan TBC aktif berbeda antara ...
# 310  Apa yang harus dilakukan jika terpapar bakteri...
# 311  Apa yang harus dilakukan jika hasil tes menunj...
# 312                                 Apa itu TBC laten?
# 313                                  Apa itu TB laten?
# 314                        Jelaskan tentang TBC laten.
# 315  Apa yang terjadi pada tubuh selama fase TBC la...
# 316                Apa yang dimaksud dengan TBC laten?
# 317       Apa yang harus diperhatikan dalam TBC laten?
# 318  Bagaimana cara mengetahui jika seseorang memil...
# 319                         Apa gejala dari TBC laten?
# 320  Bagaimana TBC laten bisa berkembang menjadi ak...
# 321            Jelaskan secara detail apa itu tb laten
# 322      Apa perbedaan antara TBC laten dan TBC aktif?
# 323                Bagaimana cara diagnosis TBC laten?
# 324           Jelaskan secara detail apa itu tbc laten
# 325  Apa yang harus dilakukan jika seseorang didiag...
# 326  Bagaimana TBC laten mempengaruhi sistem kekeba...
# 327  Apa yang harus dilakukan untuk mencegah TBC la...
# 328     Apa langkah-langkah perawatan untuk TBC laten?
# 329            Apakah TBC laten menular ke orang lain?
# 330      Apa yang menyebabkan TBC laten menjadi aktif?
# 331  Bagaimana cara mengatasi TBC laten untuk mence...
# 332    Bagaimana pengobatan untuk TBC laten dilakukan?
# 333  Apa yang harus diperhatikan dalam pemantauan T...
# 334  Apa gejala awal yang harus diperhatikan jika T...
# 335  Berapa lama seseorang bisa tetap dengan TBC la...
# 336  Apa risiko kesehatan jika TBC laten tidak diob...
# 337  Bagaimana cara mengetahui apakah TBC laten say...
# 338                                            TB Paru
# 339                                           TBC paru
# 340                                  Apa itu TBC paru?
# 341                                   Apa itu TB paru?
# 342        Apa yang dimaksud dengan tuberkulosis paru?
# 343                         Jelaskan tentang TBC paru.
# 344   Bagaimana TBC paru berbeda dari TBC ekstra paru?
# 345                             Apa penyebab TBC paru?
# 346              Bagaimana TBC mempengaruhi paru-paru?
# 347                  Bagaimana cara TBC paru menyebar?
#
#                                              responses
# 0    [Halo! Selamat datang di chatbot LISA, asisten...
# 1    [Halo! Selamat datang di chatbot LISA, asisten...
# 2    [Halo! Selamat datang di chatbot LISA, asisten...
# 3    [Halo! Selamat datang di chatbot LISA, asisten...
# 4    [Halo! Selamat datang di chatbot LISA, asisten...
# 5    [Halo! Selamat datang di chatbot LISA, asisten...
# 6    [Halo! Selamat datang di chatbot LISA, asisten...
# 7    [Halo! Selamat datang di chatbot LISA, asisten...
# 8    [Halo! Selamat datang di chatbot LISA, asisten...
# 9    [Halo! Selamat datang di chatbot LISA, asisten...
# 10   [Halo! Selamat datang di chatbot LISA, asisten...
# 11   [Halo! Selamat datang di chatbot LISA, asisten...
# 12   [Halo! Selamat datang di chatbot LISA, asisten...
# 13   [Halo! Selamat datang di chatbot LISA, asisten...
# 14   [Halo! Selamat datang di chatbot LISA, asisten...
# 15   [Selamat pagi. Bagaimana perasaan kamu hari ini?]
# 16   [Selamat pagi. Bagaimana perasaan kamu hari ini?]
# 17     [Selamat siang. Bagaimana kabar kamu hari ini?]
# 18     [Selamat siang. Bagaimana kabar kamu hari ini?]
# 19   [Selamat sore. Apa yang bisa LISA bantu hari i...
# 20   [Selamat sore. Apa yang bisa LISA bantu hari i...
# 21              [Selamat malam. Bagaimana kabar kamu?]
# 22              [Selamat malam. Bagaimana kabar kamu?]
# 23   [Sampai jumpa lagi., Semoga harimu menyenangka...
# 24   [Sampai jumpa lagi., Semoga harimu menyenangka...
# 25   [Sampai jumpa lagi., Semoga harimu menyenangka...
# 26   [Sampai jumpa lagi., Semoga harimu menyenangka...
# 27   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 28   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 29   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 30   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 31   [Sama-sama!, Dengan senang hati!, Kapan pun!, ...
# 32   [Maaf, saya tidak mengerti., Silakan lanjutkan...
# 33   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 34   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 35   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 36   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 37   [Saya adalah LISA (Lampung Sehat Asistant). Sa...
# 38   [Saya bisa memberikan informasi umum tentang T...
# 39   [Saya bisa memberikan informasi umum tentang T...
# 40   [Saya bisa memberikan informasi umum tentang T...
# 41   [Saya bisa memberikan informasi umum tentang T...
# 42   [Saya bisa memberikan informasi umum tentang T...
# 43   [Saya bisa memberikan informasi umum tentang T...
# 44   [Saya bisa memberikan informasi umum tentang T...
# 45   [Saya dikembangkan oleh tim Inisiatif Lampung ...
# 46   [Saya dikembangkan oleh tim Inisiatif Lampung ...
# 47   [Saya dikembangkan oleh tim Inisiatif Lampung ...
# 341  [TB Paru adalah infeksi yang terjadi di paru-p...
# 342  [TB Paru adalah infeksi yang terjadi di paru-p...
# 343  [TB Paru adalah infeksi yang terjadi di paru-p...
# 344  [TB Paru adalah infeksi yang terjadi di paru-p...
# 345  [TB Paru adalah infeksi yang terjadi di paru-p...
# 346  [TB Paru adalah infeksi yang terjadi di paru-p...
# 347  [TB Paru adalah infeksi yang terjadi di paru-p...

# %%
df['tag'].unique()
# Out:
# array(['salam', 'pagi', 'siang', 'sore', 'malam', 'penutup',
#        'terima_kasih', 'tidak_respon', 'tentang_saya', 'kemampuan',
#        'pembuat', 'nama', 'bantuan', 'apa_itu_tb', 'gejala_tb',
#        'penyebab_tb', 'penularan_tb', 'risiko_tb', 'proses_infeksi_tb',
#        'perbedaan_tb_aktif_tb_laten', 'tb_aktif', 'tb_laten', 'tb_paru'],
#       dtype=object)

# %%
from keras._tf_keras.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(lower=True, split=' ')
tokenizer.fit_on_texts(df['patterns'])
tokenizer.get_config()
# Out:
# {'num_words': None,
#  'filters': '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#  'lower': True,
#  'split': ' ',
#  'char_level': False,
#  'oov_token': None,
#  'document_count': 348,
#  'word_counts': '{"hai": 1, "hei": 1, "hi": 1, "halo": 1, "hola": 1, "hello": 1, "wassap": 1, "yuhuu": 1, "ada": 1, "yang": 67, "di": 5, "sana": 1, "selamat": 9, "pagi": 3, "siang": 3, "sore": 3, "malam": 3, "apakah": 5, "ini": 4, "chatbot": 2, "tuberkulosis": 40, "tbc": 195, "tinggal": 1, "sampai": 1, "jumpa": 1, "dadah": 1, "goodbye": 1, "terima": 3, "kasih": 3, "makasih": 1, "itu": 24, "sangat": 1, "membantu": 2, "atas": 1, "bantuannya": 1, "infonya": 1, "ceritakan": 1, "tentang": 8, "dirimu": 2, "siapa": 23, "kamu": 11, "apa": 120, "lakukan": 3, "namamu": 1, "bisa": 21, "bantu": 4, "kemampuanmu": 1, "dapat": 4, "saja": 12, "membuatmu": 1, "bagaimana": 59, "dibuat": 1, "penciptamu": 1, "nama": 1, "saya": 17, "bernama": 1, "panggil": 1, "bisakah": 2, "tolong": 5, "butuh": 1, "bantuan": 1, "dukung": 1, "ya": 2, "tb": 60, "jelasin": 3, "tuberculosis": 10, "penyakit": 12, "sih": 1, "kenapa": 5, "singkat": 1, "gimana": 2, "jelaskan": 12, "adalah": 2, "pengertian": 2, "dimaksud": 4, "dengan": 9, "ketahui": 2, "gejala": 36, "ciri": 9, "tanda": 13, "utama": 5, "awal": 5, "umum": 2, "kalau": 1, "dari": 10, "cara": 23, "mengetahui": 4, "jika": 12, "terkena": 10, "harus": 21, "waspadai": 1, "untuk": 10, "mengalami": 2, "umumnya": 1, "muncul": 1, "pada": 11, "pasien": 3, "sering": 1, "dialami": 1, "seseorang": 7, "merasa": 1, "tidak": 6, "sehat": 1, "menunjukkan": 4, "perlu": 2, "diperhatikan": 8, "perbedaan": 6, "antara": 6,
ras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder 

ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])  # Mengonversi teks pola menjadi urutan angka
X = pad_sequences(ptrn2seq, padding='post')  # Melakukan padding terhadap urutan angka
print('X shape = ', X.shape)  # Menampilkan bentuk (shape) dari X

lbl_enc = LabelEncoder()  # Membuat objek LabelEncoder
y = lbl_enc.fit_transform(df['tag'])  # Mengonversi label kelas menjadi angka
print('y shape = ', y.shape)  # Menampilkan bentuk (shape) dari y
print('num of classes = ', len(np.unique(y)))  # Menampilkan jumlah kelas unik
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 from keras._tf_keras.keras.preprocessing.sequence import pad_sequences
# ----> 2 from sklearn.preprocessing import LabelEncoder
#       4 ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])  # Mengonversi teks pola menjadi urutan angka
#       5 X = pad_sequences(ptrn2seq, padding='post')  # Melakukan padding terhadap urutan angka
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import tensorflow
from tensorflow import keras
from keras._tf_keras.keras.models import Sequential
from keras._tf_keras.keras.layers import Input, Embedding, LSTM, LayerNormalization, Dense, Dropout
from keras._tf_keras.keras.utils import plot_model

model = Sequential()  # Membuat model Sequential

# Menambahkan lapisan-lapisan ke dalam model
model.add(Input(shape=(X.shape[1],)))  # Lapisan input dengan bentuk sesuai dengan X
model.add(Embedding(input_dim=vocab_size+1, output_dim=100, mask_zero=True))  # Lapisan embedding dengan vocab_size + 1 sebagai input_dim
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM kedua dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32))  # Lapisan LSTM ketiga dengan 32 unit
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dense(128, activation="relu"))  # Lapisan dense dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout dengan tingkat dropout 0.2
model.add(Dense(128, activation="relu"))  # Lapisan dense kedua dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout kedua dengan tingkat dropout 0.2
model.add(Dense(len(np.unique(y)), activation="softmax"))  # Lapisan dense terakhir dengan jumlah unit sesuai dengan jumlah kelas dan fungsi aktivasi softmax

model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])  # Mengompilasi model dengan optimizer Adam, fungsi loss sparse_categorical_crossentropy, dan metrik akurasi

model.summary()  # Menampilkan ringkasan model
plot_model(model, show_shapes=True)  # Menampilkan struktur visual model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       7 model = Sequential()  # Membuat model Sequential
#       9 # Menambahkan lapisan-lapisan ke dalam model
# ---> 10 model.add(Input(shape=(X.shape[1],)))  # Lapisan input dengan bentuk sesuai dengan X
#      11 model.add(Embedding(input_dim=vocab_size+1, output_dim=100, mask_zero=True))  # Lapisan embedding dengan vocab_size + 1 sebagai input_dim
#      12 model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM dengan 32 unit dan return_sequences=True
#
# NameError: name 'X' is not defined

# %%
model_history = model.fit(x=X,  # Data input X
                          y=y,  # Data output y
                          batch_size=64,  # Ukuran batch yang digunakan dalam setiap iterasi
                          callbacks=[tensorflow.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)],  # Menggunakan EarlyStopping untuk menghentikan pelatihan jika akurasi tidak meningkat setelah 3 epoch
                          epochs=50,
                          shuffle=False)  # Jumlah epoch (iterasi) pelatihan
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0524 - loss: 4.2772
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2359 - loss: 2.7663
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3298 - loss: 2.2194
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4080 - loss: 1.9112
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5559 - loss: 1.5853
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6452 - loss: 1.2774
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7118 - loss: 1.0809
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7655 - loss: 0.9075
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7611 - loss: 0.8618
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8339 - loss: 0.6877
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8518 - loss: 0.6173
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8712 - loss: 0.5246
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8806 - loss: 0.4811
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8748 - loss: 0.4889
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9301 - loss: 0.3398
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9023 - loss: 0.3565
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9228 - loss: 0.3106
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9261 - loss: 0.2960

# %%
import re
import random

def inputan_user(pattern):
    # Preprocess input pattern
    text = []
    txt = re.sub('[^a-zA-Z\']', ' ', pattern)  # Menghapus karakter selain huruf dan tanda kutip
    txt = txt.lower()  # Mengonversi ke huruf kecil
    txt = txt.split()  # Memisahkan menjadi kata
    txt = " ".join(txt)  # Menggabungkan kembali menjadi string
    text.append(txt)  # Menambahkan ke dalam list

    # Tokenize and pad the input pattern
    x_test = tokenizer.texts_to_sequences(text)  # Mengonversi teks input menjadi urutan angka
    x_test = pad_sequences(x_test, padding='post', maxlen=X.shape[1])  # Melakukan padding

    # Make prediction using the model
    y_pred = model.predict(x_test)  # Prediksi kelas
    y_pred = y_pred.argmax()  # Mengambil indeks dengan probabilitas tertinggi
    tag = lbl_enc.inverse_transform([y_pred])[0]  # Mengonversi indeks kembali menjadi label kelas

    # Fetch possible responses based on predicted tag
    responses = df[df['tag'] == tag]['responses'].values
    if len(responses) > 0:  # Periksa apakah ada respons yang tersedia
        response = random.choice(responses[0])  # Ambil respons acak
    else:
        response = "Maaf, saya tidak dapat menemukan jawaban untuk pertanyaan Anda."

    # Display user input and bot response
    print("User: {}".format(pattern))
    print("BOT : {}".format(response))  # Menampilkan respons bot

# %% [markdown]
# Menyimpan Model

# %%
# Menyimpan model ke file
model.save('../models/LISAv2.keras')

# %%
inputan_user('')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# User: hi
# BOT : Halo! Bagaimana kabarmu? Jika kamu memiliki pertanyaan seputar Tuberkulosis, jangan ragu untuk bertanya.

# %%
inputan_user('bisakah kamu menjawab 2 pertanyaan')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# User: bisakah kamu menjawab 2 pertanyaan
# BOT : Selamat pagi. Bagaimana perasaan kamu hari ini?

# %%
inputan_user('saya')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# User: saya
# BOT : Selamat pagi. Bagaimana perasaan kamu hari ini?

# %%
inputan_user("what is depression?")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# User: what is depression?
# BOT : Silakan lanjutkan.

# %%
inputan_user("How do i know if i have Depression?	")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# User: How do i know if i have Depression?
# BOT : Maaf, saya tidak mengerti.

# %%
inputan_user("Are there cures for mental health problems?	")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# User: Are there cures for mental health problems?
# BOT : Silakan lanjutkan.

# %%
inputan_user("How can I maintain social connections?")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# User: How can I maintain social connections?
#  BOT : A lot of people are alone right now, but we don't have to be lonely. We're all in this together. Think about the different ways to connect that are most meaningful for you. For example, you might prefer a video chat over a phone call, or you might prefer to text throughout the day rather than one set time for a video call. Then, work with your social networks to make a plan. You might video chat with your close friends in the evening and phone a family member once a week. Remember to be mindful of people who may not be online. Check in by phone and ask how you can help. The quality of your social connections matter. Mindlessly scrolling through social media and liking a few posts usually doesn't build strong social connections. Make sure you focus on strategies that actually make you feel included and connected. If your current strategies don't help you feel connected, problem-solve to see if you can find a solution. Everyone feels lonely at times. Maybe you recently moved to a new city, are changing your circle of friends, lost someone important in your life, or lost your job and also lost important social connections with coworkers. Other people may have physical connections to others but may feel like their emotional or social needs aren't met. Measures like social distancing or self-isolation can make loneliness feel worse no matter why you feel lonely now. Reach out to the connections you do have. Suggest ways to keep in touch and see if you can set a regular time to connect. People may hesitate to reach out for a lot of different reasons, so don't be afraid to be the one who asks. Look for local community support groups and mutual aid groups on social media. This pandemic is bringing everyone together, so look for opportunities to make new connections. These groups are a great way to share your skills and abilities or seek help and support. Look for specialized support groups. Support groups are moving online, and there are a lot of different support lines to call if you need to talk to someone.

# %%
inputan_user("Good Night")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# User: Good Night
#  BOT : Good night. Sweet dreams.

# %%
inputan_user("Good morning")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# User: Good morning
#  BOT : Good morning. How are you feeling today?

# %%
inputan_user("Good evening")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# User: Good evening
#  BOT : Good evening. How has your day been?

# %%
inputan_user("intro please")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# User: intro please
#  BOT : I'm MentalHealthBot, your Personal Mental Bot assistance. do you need my help?

# %%
inputan_user("what is depression?")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# User: what is depression?
#  BOT : Depression is a mental health disorder characterized by persistent feelings of sadness, hopelessness, and a lack of interest or pleasure in activities. It goes beyond normal feelings of sadness and can impact various aspects of life. Depression is a treatable condition, and seeking professional help is crucial for an accurate diagnosis and appropriate treatment.

# %%
inputan_user("What is anxiety?")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# User: What is anxiety?
#  BOT : Anxiety is a natural response to stress, characterized by feelings of fear, apprehension, or uneasiness. While stress is a response to a specific threat, anxiety is often more generalized and can persist even when there is no immediate danger. Anxiety disorders involve excessive and persistent worry that can interfere with daily life. It's essential to distinguish between normal anxiety and anxiety disorders, as the latter may require professional intervention.

# %%
#Menyimpan model setelah pelatihan
model.save('my_model.keras')

# %%
inputan_user("may i ask u something?")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# User: may i ask u something?
#  BOT : Sure. I'll try my best to answer you
